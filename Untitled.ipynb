# %% [markdown]
# # Solas Summer School Practical

# %% [markdown]
# - Tiny particles in the atmosphere.
# - Primary ones are emited directly from the source
# - Aerosol from the sea spray
#
# They have a huge importance on the climate. Carbon aerosols heat the earth system. Not effective at all in the region.
#
# Black carbon difficulty is much higher, they have many different sources. They can have different ways with the light and is really hard to characterize them. Investigate the relative effects of the Black carbon.
#
# Aerosols are mainly described in the
# - Red light regime, particles are much smaller. Orders of magnitude
# - Aerosols are so tiny they have sizes in the order of the wavelength.
#
# Aerosols can cool the system. They have this huge effect , radiation interaction and how they affect the system.
#
# **OAD, SAOD and AAOD**
#
# Aerosol physical processes. Aerosol properties, we split both in two groups:
#
# - Not dependent on aerosol class
# - Extensive properties, depend on the size distribution

# %%
# !git clone https://github.com/marcomac27/paper_AERONET_RI.git
# Out:
# Cloning into 'paper_AERONET_RI'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 34 (delta 11), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (34/34), 1.99 MiB | 5.13 MiB/s, done.
# Resolving deltas: 100% (11/11), done.
