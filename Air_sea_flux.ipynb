# %% [markdown]
# # Air sea flux

# %%
# !pip install fluxengine
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.0/148.0 MB 9.8 MB/s  0:00:156m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [fluxengine]4 [fluxengine]
# ...

# %%
# !git clone https://github.com/oceanflux-ghg/FluxEngine.git
# !git clone https://github.com/JamieLab/Teaching.git
# Out:
# Cloning into 'Teaching'...
# remote: Enumerating objects: 741, done.
# remote: Counting objects: 100% (741/741), done.
# remote: Compressing objects: 100% (420/420), done.
# remote: Total 741 (delta 347), reused 688 (delta 307), pack-reused 0 (from 0)
# Receiving objects: 100% (741/741), 23.07 MiB | 15.06 MiB/s, done.
# Resolving deltas: 100% (347/347), done.
